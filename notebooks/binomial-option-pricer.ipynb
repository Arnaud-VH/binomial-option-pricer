# %% [markdown]
# # Binomial Option Pricer
# - By Davide Onorio (64658), Nicolas Arboleda (64690), Arnaud Van Hees (64691), and Yuan Chen Ding (64667)

# %% [markdown]
# ### Project Parts
# 1. Introduction
# 2. Theoretical Background of option pricing
#    1. One step, Two step, N step model
#    2. Explanation of Python implementation approach
#
# 3. Imports
#    1. Different packages we import like numpy, MatPlotLib
# 4. CRR Option Pricer implementation
#    1. Use of pre-defined values (imaginary)
# 5. Small Bionomial Tree Visualisation
#    1. Using MatPlotLib package
# 6. Example with real market data
#    1. Using Yahoo Finance (Pre-defined)
#    2. Letting user decide on stocks (User Input)
#
#
# Possible Extensions:
#
# 7. American Options
# 8. Adding Dividends
# 9. GUI with sliders
# 10. Convergence to Black-Scholes
# 11. Add docstrings to the code

# %% [markdown]
# # Introduction
